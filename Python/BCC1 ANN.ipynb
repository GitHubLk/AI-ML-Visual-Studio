# %%
import tensorflow
from tensorflow import keras 
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

model.add(Dense(3, activation='relu', input_shape=(30,)))
model.add(Dense(3, activation='relu'))
model.add(Dense(3, activation='sigmoid'))

# %%
import pandas as pd
import tensorflow
from tensorflow import keras 
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()

model.add(Dense(3, activation='relu', input_shape=(30,)))
model.add(Dense(3, activation='relu'))
model.add(Dense(3, activation='sigmoid'))

from sklearn.datasets import fetch_openml

df = pd.read_csv("data.csv")

#dataset = fetch_openml(name='credit-g', version=1, as_frame=True)

#x = dataset.data
#y = dataset.target

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y = encoder.fit_transform(y)

# One-hot encode categorical features BEFORE splitting
x = pd.get_dummies(x, drop_first=True)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=0
)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Do not change any other parts of the code
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

classifier = MLPClassifier(
    hidden_layer_sizes=(100, 100, 100),
    activation='relu',
    solver='adam',
    batch_size=20,
    max_iter=100,
    random_state=0
)

classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred) * 100)
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 71.5
# Confusion Matrix:
# [[ 29  29]
#  [ 28 114]]

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix


df = pd.read_csv("data.csv")



# Drop ID column if it exists
if 'id' in df.columns:
    df = df.drop(columns=['id'])

X = df.drop(columns=['diagnosis'])
y = df['diagnosis']

# Keep only numeric features
X = X.select_dtypes(include=['number'])


# Encode target (M=1, B=0)

encoder = LabelEncoder()
y = encoder.fit_transform(y)


# Train-test split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)


# Feature scaling

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)


# Build ANN

model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


# Compile ANN

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)


# Train ANN

model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=16,
    verbose=1
)


y_pred = (model.predict(X_test) > 0.5).astype(int)

print("Accuracy:", accuracy_score(y_test, y_pred) * 100)
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Epoch 1/50
# c:\Users\Naz\anaconda3\envs\tf_env\lib\site-packages\sklearn\utils\extmath.py:1144: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# c:\Users\Naz\anaconda3\envs\tf_env\lib\site-packages\sklearn\utils\extmath.py:1149: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# c:\Users\Naz\anaconda3\envs\tf_env\lib\site-packages\sklearn\utils\extmath.py:1169: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# c:\Users\Naz\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6374 - loss: 0.6916
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6886
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6858
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6374 - loss: 0.6834
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6811
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6374 - loss: 0.6790
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6374 - loss: 0.6771
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6754
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6374 - loss: 0.6736
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6722
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6374 - loss: 0.6706
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6374 - loss: 0.6694
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6682
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6671
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6374 - loss: 0.6660
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6374 - loss: 0.6650
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6374 - loss: 0.6642
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6634
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6627
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6374 - loss: 0.6620
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6374 - loss: 0.6614
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6374 - loss: 0.6608
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6374 - loss: 0.6603
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6374 - loss: 0.6598
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6593
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6590
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6585
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6374 - loss: 0.6582
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6580
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6576
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6574
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6572
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6570
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6568
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6567
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6565
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6563
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6562
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6561
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6560
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6559
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6374 - loss: 0.6558
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6374 - loss: 0.6557
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6557
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6556
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6555
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6555
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6555
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.6554
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.6554
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Accuracy: 58.77192982456141
# Confusion Matrix:
# [[67  0]
#  [47  0]]
